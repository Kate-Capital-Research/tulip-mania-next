# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown
from tulip.data.bloomberg import BloombergClient as bb
from tulip.plots import plot_curve
from tulip.utils.notebook_related import display_table_and_chart
from xbbg import blp
import pycountry

from tulip.data.collections.collections_bloomberg import (
    POLICY_RATES,
    WIRP,
    CURVES,
    COUNTRY_CURRENCY,
    OVERNIGHT_RATES,
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %%
countries = [
    "US",  # United States
    "EU",  # Euro
    "GB",  # United Kingdom
    "JP",  # Japan
    "SE",  # Sweden
    "AU",  # Australia
    "CA",  # Canada
    "KR",  # South Korea
    "CN",  # China
    "IN",  # India
    "BR",  # Brazil
    # "DE",  # Germany
    # "FR",  # France
    "MX",  # Mexico
    "ZA",  #  South Africa
    # "ES",  # Spain
    # "IT",  # Italy
]

today_str = pd.Timestamp("today").strftime("%Y%m%d")
week_ago_str = (pd.Timestamp("today") - pd.offsets.BusinessDay(n=5)).strftime("%Y%m%d")
wirp_period = (pd.Timestamp("today") + pd.offsets.YearEnd()).strftime("%b%Y").upper()

bonds_markets = {
    k: {
        "pycountry": pycountry.countries.get(alpha_2=k),
        "currency": COUNTRY_CURRENCY[k],
        "WIRP": WIRP[k] if k in WIRP.keys() else None,
        "Hikes/Cuts ticker": (
            WIRP[k].replace("BPR", "BNM") if k in WIRP.keys() else None
        ),
        "Implied Rate ticker": (
            WIRP[k].replace("BPR", "BFR") if k in WIRP.keys() else None
        ),
        "Hikes/Cuts by EoY ticker": (
            WIRP[k].replace("BPR", "BNM").replace(" ", " " + wirp_period + " ")
            if k in WIRP.keys()
            else None
        ),
        "Implied Rate by EoY ticker": (
            WIRP[k].replace("BPR", "BFR").replace(" ", " " + wirp_period + " ")
            if k in WIRP.keys()
            else None
        ),
        "policy_rate_ticker": POLICY_RATES[k],
        "policy_rate": bb.bdp(POLICY_RATES[k], fields=["PX_LAST"])["px_last"].squeeze(),
        "overnight_rate_ticker": OVERNIGHT_RATES[k],
        "overnight_rate": bb.bdp(OVERNIGHT_RATES[k], fields=["PX_LAST"])[
            "px_last"
        ].squeeze(),
        "sovereign_curve_ticker": f"{CURVES['sovereign'][k]} Index",
        "sovereign_curve": blp.bds(
            f"{CURVES['sovereign'][k]} Index", flds=["CURVE_TENOR_RATES"]
        ),
        "sovereign_curve_1_week_ago": blp.bds(
            f"{CURVES['sovereign'][k]} Index",
            flds=["CURVE_TENOR_RATES"],
            curve_date=week_ago_str,
        ),
        #  "growth_ticker_QoQ":bb.bdp(f"EHGD{k} Index", fields=['PX_LAST'])['px_last'].squeeze(),
    }
    for k in countries
}

for ctry in countries:
    try:
        bonds_markets[ctry]["Hikes/Cuts by EoY"] = bb.bdp(
            bonds_markets[ctry]["Hikes/Cuts by EoY ticker"], fields=["PX_LAST"]
        )["px_last"].squeeze()
    except:
        bonds_markets[ctry]["Hikes/Cuts by EoY"] = None
    try:
        bonds_markets[ctry]["Implied Rate by EoY"] = bb.bdp(
            bonds_markets[ctry]["Implied Rate by EoY ticker"], fields=["PX_LAST"]
        )["px_last"].squeeze()
    except:
        bonds_markets[ctry]["Implied Rate by EoY"] = None

for ctry in countries:
    bonds_markets[ctry]["central_bank_wip"] = pd.Series(
        {
            "Policy Rate": bonds_markets[ctry]["policy_rate"],
            "Hike/Cuts by EOY": bonds_markets[ctry]["Hikes/Cuts by EoY"],
            "Implied Rate by EOY": bonds_markets[ctry]["Implied Rate by EoY"],
        },
        name=f"{ctry} CB expectations",
    )

for ctry in countries:
    bonds_markets[ctry]["central_bank_wip_styled"] = (
        bonds_markets[ctry]["central_bank_wip"].to_frame().style.format("{:.3f}")
    )

    title = (
        f"<b>{bonds_markets[ctry]['currency']} Sovereign Curve</b>"
        if bonds_markets[ctry]["pycountry"] is None
        else f"<b>{bonds_markets[ctry]['pycountry'].name} Sovereign Curve</b>"
    )

    bonds_markets[ctry]["curve_data"] = curve = (
        pd.DataFrame(
            {
                "Today": bonds_markets[ctry]["sovereign_curve"].set_index("tenor")[
                    "mid_yield"
                ],
                "1W ago": bonds_markets[ctry]["sovereign_curve_1_week_ago"].set_index(
                    "tenor"
                )["mid_yield"],
            }
        )
        .round(4)
        .replace(0, np.nan)
    )

    bonds_markets[ctry]["curve_fig"] = plot_curve(curve, tick_suffix="%", title=title)
    bonds_markets[ctry]["curve_fig"].add_hline(
        bonds_markets[ctry]["overnight_rate"],
        line_color="darkred",
        line_dash="dash",
        layer="above",
        opacity=0.8,
        line_width=1,
        annotation_text="Overnight Rate",
    )

overnight_rates = pd.Series({k: v["overnight_rate"] for k, v in bonds_markets.items()})

# %% [markdown]
# ### Yields Today

# %%
def transform_tenor(x):
    if x < 12:
        return ("Months", int(x))
    else:
        return ("Years", int(x / 12))


def style_scan(df):
    def hide_nan_css(v):
        return "visibility: hidden;" if pd.isna(v) else ""

    styler = df.style.background_gradient(axis=0)
    styler = styler.map(hide_nan_css).format(na_rep="", precision=2)
    return styler


todays_yields = pd.concat(
    {k: v["curve_data"]["Today"] for k, v in bonds_markets.items()}, axis=1
).sort_index()
todays_yields.index = todays_yields.index.map(lambda x: round(x, 2))
todays_yields = todays_yields.drop(1.38)

todays_yields.index = pd.MultiIndex.from_tuples(
    [transform_tenor(x) for x in todays_yields.index], names=["Period", "Value"]
)

style_scan(todays_yields.T)
# Out:
# <style type="text/css">
# #T_67e2b_row0_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_67e2b_row0_col1, #T_67e2b_row0_col3, #T_67e2b_row1_col5, #T_67e2b_row3_col2, #T_67e2b_row3_col4, #T_67e2b_row3_col6, #T_67e2b_row3_col7, #T_67e2b_row3_col8, #T_67e2b_row3_col9, #T_67e2b_row3_col10, #T_67e2b_row3_col11, #T_67e2b_row3_col12, #T_67e2b_row3_col13, #T_67e2b_row3_col14, #T_67e2b_row3_col15, #T_67e2b_row3_col18, #T_67e2b_row3_col22, #T_67e2b_row4_col20, #T_67e2b_row5_col16, #T_67e2b_row7_col23, #T_67e2b_row8_col19, #T_67e2b_row8_col21, #T_67e2b_row9_col17, #T_67e2b_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T
col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_67e2b_row2_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_67e2b_row2_col7, #T_67e2b_row2_col8, #T_67e2b_row2_col13, #T_67e2b_row2_col15 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_67e2b_row2_col12 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_67e2b_row2_col14 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_67e2b_row2_col18 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_67e2b_row2_col19 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_67e2b_row2_col21, #T_67e2b_row9_col9 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_67e2b_row2_col22 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_67e2b_row2_col23 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_67e2b_row3_col19 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_67e2b_row3_col21 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_67e2b_row4_col2, #T_67e2b_row4_col14 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_67e2b_row4_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_67e2b_row4_col18 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_67e2b_row4_col23, #T_67e2b_row8_col10 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_67e2b_row5_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_67e2b_row5_col12 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_67e2b_row5_col14 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_67e2b_row5_col18 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_67e2b_row5_col19 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_67e2b_row5_col21 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_67e2b_row6_col0, #T_67e2b_row11_col10 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_67e2b_row6_col2 {
#   background-color: #ced0e6;
#   color: #00

# %%
spreadsto1s = todays_yields.T.loc[:, pd.IndexSlice["Years", [10, 20, 30]]].sub(
    todays_yields.T.loc[:, pd.IndexSlice["Years", 1]].squeeze(), axis=0
)
spreadsto1s.columns = pd.MultiIndex.from_product(
    [["Spreads1sXs"], [10, 20, 30]], names=spreadsto1s.columns.names
)
spreadsto2s = todays_yields.T.loc[:, pd.IndexSlice["Years", [10, 20, 30]]].sub(
    todays_yields.T.loc[:, pd.IndexSlice["Years", 2]].squeeze(), axis=0
)
spreadsto2s.columns = pd.MultiIndex.from_product(
    [["Spreads2sXs"], [10, 20, 30]], names=spreadsto2s.columns.names
)
style_scan(pd.concat([spreadsto1s, spreadsto2s], axis=1))
# Out:
# <style type="text/css">
# #T_e4e26_row0_col0, #T_e4e26_row6_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_e4e26_row0_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e4e26_row0_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e4e26_row0_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_e4e26_row0_col4 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_e4e26_row0_col5 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e4e26_row1_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_e4e26_row1_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e4e26_row1_col2, #T_e4e26_row1_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e4e26_row1_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_e4e26_row1_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_e4e26_row2_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_e4e26_row2_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e4e26_row2_col2 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_e4e26_row2_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e4e26_row2_col4 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_e4e26_row2_col5, #T_e4e26_row9_col5 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_e4e26_row3_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_e4e26_row3_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_e4e26_row3_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_e4e26_row3_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e4e26_row3_col4 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_e4e26_row3_col5, #T_e4e26_row11_col3, #T_e4e26_row12_col0, #T_e4e26_row12_col1, #T_e4e26_row12_col2, #T_e4e26_row12_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e4e26_row4_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_e4e26_row4_col1, #T_e4e26_row4_col2, #T_e4e26_row4_col4, #T_e4e26_row4_col5, #T_e4e26_row8_col3, #T_e4e26_row8_col4, #T_e4e26_row8_col5, #T_e4e26_row10_col1, #T_e4e26_row10_col2, #T_e4e26_row10_col4, #T_e4e26_row10_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   visibility: hidden;
# }
# #T_e4e26_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e4e26_row5_col0, #T_e4e26_row5_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_e4e26_row5_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_e4e26_row5_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_e4e26_row5_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_e4e26_row5_col5 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_e4e26_row6_col0 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_e4e26_row6_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_e4e26_row6_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_e4e26_row6_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_e4e26_row6_col5, #T_e4e26_row9_col4 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_e4e26_row7_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_e4e26_row7_col1, #T_e4e26_row8_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e4e26_row7_col2, #T_e4e26_row7_col3, #T_e4e26_row7_col4, #T_e4e26_row7_col5, #T_e4e26_row8_col1, #T_e4e26_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e4e26_row8_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e4e26_row9_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_e4e26_row9_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_e4e26_row9_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_e4e26_row9_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_e4e26_row10_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e4e26_row11_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_e4e26_row11_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_e4e26_row11_col2 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_e4e26_row11_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_e4e26_row11_col5 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_e4e26_row12_col3 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_e4e26_row12_col5 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4e26">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Period</th>
#       <th id="T_e4e26_level0_col0" class="col_heading level0 col0" colspan="3">Spreads1sXs</th>
#       <th id="T_e4e26_level0_col3" class="col_heading level0 col3" colspan="3">Spreads2sXs</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Value</th>
#       <th id="T_e4e26_level1_col0" class="col_heading level1 col0" >10</th>
#       <th id="T_e4e26_level1_col1" class="col_heading level1 col1" >20</th>
#       <th id="T_e4e26_level1_col2" class="col_heading level1 col2" >30</th>
#       <th id="T_e4e26_level1_col3" class="col_heading level1 col3" >10</th>
#       <th id="T_e4e26_level1_col4" class="col_heading level1 col4" >20</th>
#       <th id="T_e4e26_level1_col5" class="col_heading level1 col5" >30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4e26_level0_row0" class="row_heading level0 row0" >US</th>
#       <td id="T_e4e26_row0_col0" class="data row0 col0" >0.42</td>
#       <td id="T_e4e26_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_e4e26_row0_col2" class="data row0 col2" >1.01</td>
#       <td id="T_e4e26_row0_col3" class="data row0 col3" >0.50</td>
#       <td id="T_e4e26_row0_col4" class="data row0 col4" >1.07</td>
#       <td id="T_e4e26_row0_col5" class="data row0 col5" >1.10</td>
#     </tr>
#     <tr>
#       <th id="T_e4e26_level0_row1" class="row_heading level0 row1" >EU</th>
#       <td id="T_e4e26_row1_col0" class="data row1 col0" >0.57</td>
#       <td id="T_e4e26_row1_col1" class="data row1 col1" >1.05</td>
#       <td id="T_e4e26_row1_col2" class="data row1 col2" >1.16</td>
#       <td id="T_e4e26_row1_col3" class="data row1 col3" >0.65</td>
#       <td id="T_e4e26_row1_col4" class="data row1 col4" >1.13</td>
#       <td id="T_e4e26_row1_col5" class="data row1 col5" >1.23</td>
#     </tr>
#     <tr>
#       <th id="T_e4e26_level0_row2" class="row_heading level0 row2" >GB</th>
#       <td id="T_e4e26_row2_col0" class="data row2 col0" >0.72</td>
#       <td id="T_e4e26_row2_col1" class="data row2 col1" >1.39</td>
#       <td id="T_e4e26_row2_col2" class="data row2 col2" >1.51</td>
#       <td id="T_e4e26_row2_col3" class="data row2 col3" >0.67</td>
#       <td id="T_e4e26_row2_col4" class="data row2 col4" >1.34</td>
#       <td id="T_e4e26_row2_col5" class="data row2 col5" >1.47</td>
#     </tr>
#     <tr>
#       <th id="T_e4e26_level0_row3" class="row_heading level0 row3" >JP</th>
#       <td id="T_e4e26_row3_col0" class="data row3 col0" >0.96</td>
#       <td id="T_e4e26_row3_col1" class="data row3 col1" >1.97</td>
#       <td id="T_e4e26_row3_col2" class="data row3 col2" >2.46</td>
#       <td id="T_e4e26_row3_col3" class="data row3 col3" >0.75</td>
#       <td id="T_e4e26_row3_col4" class="data row3 col4" >1.75</td>
#       <td id="T_e4e26_row3_col5" class="data row3 col5" >2.25</td>
#     </tr>
#     <tr>
#       <th id="T_e4e26_level0_row4" class="row_heading level0 row4" >SE</th>
#       <td id="T_e4e26_row4_col0" class="data row4 col0" >0.81</td>
#       <td id="T_e4e26_row4_col1" class="data row4 col1" ></td>
#       <td id="T_e4e26_row4_col2" class="data row4 col2" ></td>
#       <td id="T_e4e26_row4_col3" class="data row4 col3" >0.68</td>
#       <td id="T_e4e26_row4_col4" class="data row4 col4" ></td>
#       <td id="T_e4e26_row4_col5" class="data row4 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_e4e26_level0_row5" class="row_heading level0 row5" >AU</th>
#       <td id="T_e4e26_row5_col0" class="data row5 col0" >0.73</td>
#       <td id="T_e4e26_row5_col1" class="data row5 col1" >1.27</td>
#       <td id="T_e4e26_row5_col2" class="data row5 col2" >1.34</td>
#       <td id="T_e4e26_row5_col3" class="data row5 col3" >0.74</td>
#       <td id="T_e4e26_row5_col4" class="data row5 col4" >1.28</td>
#       <td id="T_e4e26_row5_col5" class="dat

# %% [markdown]
# ### Country Deepdives

# %%
for ctry in countries:
    display_table_and_chart(
        table=bonds_markets[ctry]["central_bank_wip_styled"],
        chart=bonds_markets[ctry]["curve_fig"],
    )
# Out:
# <div style='display: flex; justify-content: center; align-items: center; width: 100%; overflow-x: auto; flex-wrap: wrap;'><div style="box-sizing:border-box; padding:0 10px; width:30%; min-width:300px; max-width:100%;"><style type="text/css">
# </style>
# <table id="T_ac6bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac6bb_level0_col0" class="col_heading level0 col0" >US CB expectations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac6bb_level0_row0" class="row_heading level0 row0" >Policy Rate</th>
#       <td id="T_ac6bb_row0_col0" class="data row0 col0" >4.000</td>
#     </tr>
#     <tr>
#       <th id="T_ac6bb_level0_row1" class="row_heading level0 row1" >Hike/Cuts by EOY</th>
#       <td id="T_ac6bb_row1_col0" class="data row1 col0" >-0.594</td>
#     </tr>
#     <tr>
#       <th id="T_ac6bb_level0_row2" class="row_heading level0 row2" >Implied Rate by EOY</th>
#       <td id="T_ac6bb_row2_col0" class="data row2 col0" >3.730</td>
#     </tr>
#   </tbody>
# </table>
# </div><div style="box-sizing:border-box; padding:0 10px; width:70%; min-width:300px; max-width:100%;"><div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="00593704-dd4a-4837-833a-0b441b89f0e7" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("00593704-dd4a-4837-833a-0b441b89f0e7")) {                    Plotly.newPlot(                        "00593704-dd4a-4837-833a-0b441b89f0e7",                        [{"name":"Today","x":{"dtype":"f8","bdata":"AAAAAAAA8D92Q38QKBj2PwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABhAAAAAAAAAKEAAAAAAAAA4QAAAAAAAAEJAAAAAAAAATkAAAAAAAABVQAAAAAAAAF5AAAAAAAAAbkAAAAAAAIB2QA=="},"y":{"dtype":"f8","bdata":"UI2XbhKDD0AEVg4tsp0PQHNoke18Pw9AAAAAAAAAD0DXo3A9CtcOQNEi2\u002fl+ag5ACKwcWmQ7DUCPwvUoXI8MQOXQItv5fgxAx0s3iUFgDUCiRbbz\u002fdQOQEjhehSuRxBAPzVeukmMEkApXI\u002fC9agSQA=="},"type":"scatter"},{"name":"1W ago","x":{"dtype":"f8","bdata":"AAAAAAAA8D92Q38QKBj2PwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABhAAAAAAAAAKEAAAAAAAAA4QAAAAAAAAEJAAAAAAAAATkAAAAAAAABVQAAAAAAAAF5AAAAAAAAAbkAAAAAAAIB2QA=="},"y":{"dtype":"f8","bdata":"PQrXo3A9D0BGtvP91HgPQHsUrkfheg9A30+Nl24SD0DsUbgehesOQFpkO99PjQ5AObTIdr6fDUB1kxgEVg4NQMl2vp8aLw1A6SYxCKwcDkCamZmZmZkPQKRwPQrXoxBArBxaZDvfEkDByqFFtvMSQA=="},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d" ...
# <div style='display: flex; justify-content: center; align-items: center; width: 100%; overflow-x: auto; flex-wrap: wrap;'><div style="box-sizing:border-box; padding:0 10px; width:30%; min-width:300px; max-width:100%;"><style type="text/css">
# </style>
# <table id="T_af954">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af954_level0_col0" class="col_heading level0 col0" >EU CB expectations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af954_level0_row0" class="row_heading level0 row0" >Policy Rate</th>
#       <td id="T_af954_row0_col0" class="data row0 col0" >2.150</td>
#     </tr>
#     <tr>
#       <th id="T_af954_level0_row1" class="row_heading level0 row1" >Hike/Cuts by EOY</th>
#       <td id="T
},"type":"scatter"},{"name":"1W ago","x":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAAAIQAAAAAAAABhAAAAAAAAAKEAAAAAAAAA4QAAAAAAAAEJAAAAAAAAASEAAAAAAAABOQAAAAAAAAFhAAAAAAAAAXkAAAAAAAIBmQAAAAAAAAG5AAAAAAADAckAAAAAAAIB2QA=="},"y":{"dtype":"f8","bdata":"oBov3SSGHUCiRbbz\u002fdQcQOf7qfHSTR1ATmIQWDm0HUAMAiuHFlkdQP7UeOkmsR5AaJHtfD+1H0CPwvUoXE8gQKrx0k1iECFAqMZLN4nBIUCPwvUoXE8iQKRwPQrX4yJATmIQWDn0IkBOYhBYOfQiQA=="},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogr ...
# <div style='display: flex; justify-content: center; align-items: center; width: 100%; overflow-x: auto; flex-wrap: wrap;'><div style="box-sizing:border-box; padding:0 10px; width:30%; min-width:300px; max-width:100%;"><style type="text/css">
# </style>
# <table id="T_e06e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e06e3_level0_col0" class="col_heading level0 col0" >ZA CB expectations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e06e3_level0_row0" class="row_heading level0 row0" >Policy Rate</th>
#       <td id="T_e06e3_row0_col0" class="data row0 col0" >7.000</td>
#     </tr>
#     <tr>
#       <th id="T_e06e3_level0_row1" class="row_heading level0 row1" >Hike/Cuts by EOY</th>
#       <td id="T_e06e3_row1_col0" class="data row1 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e06e3_level0_row2" class="row_heading level0 row2" >Implied Rate by EOY</th>
#       <td id="T_e06e3_row2_col0" class="data row2 col0" >nan</td>
#     </tr>
#   </tbody>
# </table>
# </div><div style="box-sizing:border-box; padding:0 10px; width:70%; min-width:300px; max-width:100%;"><div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="b908f7dc-02c8-4997-b1e8-4ac9969bdb4a" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b908f7dc-02c8-4997-b1e8-4ac9969bdb4a")) {                    Plotly.newPlot(                        "b908f7dc-02c8-4997-b1e8-4ac9969bdb4a",                        [{"name":"Today","x":{"dtype":"f8","bdata":"AAAAAAAACEAAAAAAAAAYQAAAAAAAACJAAAAAAAAAKEAAAAAAAAA4QAAAAAAAAE5AAAAAAAAAUkAAAAAAAABVQAAAAAAAAFhAAAAAAAAAXkAAAAAAAIBmQAAAAAAAAG5AAAAAAADAckAAAAAAAIB2QA=="},"y":{"dtype":"f8","bdata":"HVpkO99PGUCWQ4ts5\u002fsZQMHKoUW28xlAF9nO91NjGkAj2\u002fl+ajwdQOkmMQisnB5AH4XrUbieH0B3vp8aL10gQEw3iUFgpSBAokW28\u002f1UIUBKDAIrh9YiQPhT46WbRCNAMzMzMzMzI0D2KFyPwvUiQA=="},"type":"scatter"},{"name":"1W ago","x":{"dtype":"f8","bdata":"AAAAAAAACEAAAAAAAAAYQAAAAAAAACJAAAAAAAAAKEAAAAAAAAA4QAAAAAAAAE5AAAAAAAAAUkAAAAAAAABVQAAAAAAAAFhAAAAAAAAAXkAAAAAAAIBmQAAAAAAAAG5AAAAAAADAckAAAAAAAIB2QA=="},"y":{"dtype":"f8","bdata":"H4XrUbieGUBoke18PzUaQC2yne+nRhpA30+Nl26SGkCgGi\u002fdJIYdQDeJQWDl0B5AnMQgsHLoH0B1kxgEVo4gQHe+nxov3SBAmG4Sg8CKIUDn+6nx0k0jQBKDwMqhxSNA9ihcj8K1I0DdJAaBlYMjQA=="},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogr ...

# %%
Markdown(f"_Notebook updated at {pd.Timestamp.now().strftime('%Y-%m-%d %H:%M')}_")
# Out:
# _Notebook updated at 2025-11-12 19:38_
